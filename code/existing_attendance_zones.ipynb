# %%
#written by @caramnix on 1.5.21

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import mapclassify
import maup
import gerrychain
from gerrychain import Graph, Partition, Election
import networkx as nx
import numpy as np

# %%
attendace_zones = gpd.read_file("fixed_attendance_zone/fixed_attendance_zone.shp")
attendace_zones.plot()
plt.show()

# %%
aa_assignment = maup.assign(blocks, attendace_zones)
# Out:
# /Users/caranix/%userprofile%.condaenvs/test/lib/python3.7/site-packages/maup/indexed_geometries.py:27: UserWarning: GeoSeries.isna() previously returned True for both missing (None) and empty geometries. Now, it only returns True for missing values. Since the calling GeoSeries contains empty geometries, the result has changed compared to previous versions of GeoPandas.
# Given a GeoSeries 's', you can use 's.is_empty | s.isna()' to get back the old behaviour.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', 'GeoSeries.isna', UserWarning)
#   return intersections[-(intersections.is_empty | intersections.isna())]
# ...

# %%
school_district_4269 = gpd.read_file("shapefiles/fixed_school_districts_4269/fixed_school_districts_4269.shp") #note switching epsg in python gave my issues w/ multipolygons changed it manually in python and used fixed version from GIS consultant for assignemtn to function properly 
school_district_4269.plot()
plt.show()

# %%
#also need assignement for AA to SD
assignment_aa_sd = maup.assign(attendace_zones, school_district_4269)
# Out:
# /Users/caranix/%userprofile%.condaenvs/test/lib/python3.7/site-packages/maup/intersections.py:42: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometries = geometries[geometries.area > area_cutoff]
# /Users/caranix/%userprofile%.condaenvs/test/lib/python3.7/site-packages/maup/assign.py:26: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return assign_to_max(intersections(sources, targets, area_cutoff=0).area)

# %% [markdown]
# #assignment_aa_sd

# %%
#aa_assignment
# Out:
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
#           ...
# 259772    656.0
# 259773    656.0
# 259774    656.0
# 259775    656.0
# 259776    656.0
# Length: 259777, dtype: float64

# %%
variables = ['black18', 'native18', 'asian18', 'hisp18'] #pull just these columns 
blocks[variables] = blocks[variables].apply(pd.to_numeric) 
n_white = blocks['black18'] + blocks['native18']+ blocks['asian18'] + blocks['hisp18']
blocks["non_white"] = n_white

# %%
variables = ['tot18', 'white18', 'black18', 'native18', 'asian18', 'hisp18', 'non_white'] #pull just these columns 
blocks[variables] = blocks[variables].apply(pd.to_numeric) #covert to numeric so it adds instead of making a long string

# %%
blocks[variables]
# Out:
#         tot18  white18  black18  native18  asian18  hisp18  non_white
# 0           0        0        0         0        0       0          0
# 1           7        7        0         0        0       0          0
# 2           0        0        0         0        0       0          0
# 3           4        4        0         0        0       0          0
# 4           0        0        0         0        0       0          0
# ...       ...      ...      ...       ...      ...     ...        ...
# 259772      0        0        0         0        0       0          0
# 259773      0        0        0         0        0       0          0
# 259774      0        0        0         0        0       0          0
# 259775      2        2        0         0        0       2          2
# 259776      2        2        0         0        0       0          0
#
# [259777 rows x 7 columns]

# %%
aa_assignment
# Out:
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
#           ...
# 259772    656.0
# 259773    656.0
# 259774    656.0
# 259775    656.0
# 259776    656.0
# Length: 259777, dtype: float64

# %%
variables
# Out:
# ['tot18', 'white18', 'black18', 'native18', 'asian18', 'hisp18', 'non_white']

# %%
attendace_zones[variables] = blocks[variables].groupby(aa_assignment).sum()

# %%
attendace_zones[variables].head()
# Out:
#     tot18  white18  black18  native18  asian18  hisp18  non_white
# 0  1716.0   1675.0      1.0      20.0      1.0     2.0       24.0
# 1   379.0    364.0      0.0       8.0      0.0     2.0       10.0
# 2   720.0    602.0      2.0     113.0      0.0     5.0      120.0
# 3  2260.0   1734.0    263.0      34.0    105.0   149.0      551.0
# 4   528.0    487.0     15.0       2.0     16.0    20.0       53.0

# %%
attendace_zones['index'] = list(range(770))

# %%
attendace_zones
# Out:
#           SDORGID UNI_TYP UNI_MAJ                                UNI_NAM  \
# 0    1.000100e+10      01    0001          Aitkin Public School District
# 1    1.000200e+10      01    0002       Hill City Public School District
# 2    1.000400e+10      01    0004        McGregor Public School District
# 3    1.001100e+10      01    0011  Anoka-Hennepin Public School District
# 4    1.001100e+10      01    0011  Anoka-Hennepin Public School District
# ..            ...     ...     ...                                    ...
# 765  3.000100e+10      03    0001     Minneapolis Public School District
# 766  3.000100e+10      03    0001     Minneapolis Public School District
# 767  3.000100e+10      03    0001     Minneapolis Public School District
# 768  3.000600e+10      03    0006     South St. Paul Public School Dist.
# 769  3.000600e+10      03    0006     South St. Paul Public School Dist.
#
#                            ELEM_NAME ELEM_MULTI  \
# ...

# %%
cols = list(attendace_zones.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('geometry')) #Remove b from list
#Remove x from list
attendace_zones_m = attendace_zones[cols+['geometry']]

# %%
#attendace_zones_m.to_file("attendace_zones_joined.shp")
